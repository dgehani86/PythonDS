# %%
c=10
d = 10
var = c+d

# %%
c+d
# Out:
# 20

# %%
var1=c*d
var1
# Out:
# 100

# %%
height = 1.79
weight = 68.7

# %%
weight/height **2
# Out:
# 21.44127836209856

# %%
bmi=weight/height ** 2
bmi
# Out:
# 21.44127836209856

# %%
var2 = c-d
var2
# Out:
# 0

# %%
type(bmi)
# Out:
# float

# %%
var3 = 2+3
var3
# Out:
# 5

# %%
"ab" + " " + "cd"
# Out:
# 'ab cd'

# %%
fam = ["liz", 1.73, "emma", 1.86,"mom", 1.98, "dad", 8.9]
fam
# Out:
# ['liz', 1.73, 'emma', 1.86, 'mom', 1.98, 'dad', 8.9]

# %%
fam2 = [["liz",1.73],['emma', 1.86],['mom', 1.98],['dad', 8.9]]

# %%
fam[2:-1]
# Out:
# ['emma', 1.86, 'mom', 1.98, 'dad']

# %%
fam2[2]
# Out:
# ['mom', 1.98]

# %%
fam2[-1]
# Out:
# ['dad', 8.9]

# %%
fam2[1][0] #2nd list - 1st element is again list #list with inlist
# Out:
# 'emma'

# %%
india = [["abc",1],["def",2],["gh",3]]
india
# Out:
# [['abc', 1], ['def', 2], ['gh', 3]]

# %%
india[2][1]
# Out:
# 3

# %%
fam[2:] #sliceoperate till end
# Out:
# ['emma', 1.86, 'mom', 1.98, 'dad', 8.9]

# %%
fam[:2]
# Out:
# ['liz', 1.73]

# %%
import pandas as pd
testfile1 = pd.read_csv("C:\\Users\\dgehan01\\Desktop\\python video\\test1.csv")
testfile1
# Out:
#      campaignId                     campaignName  clientId  affiliateId  \
# 0       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        24825
# 1       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25525
# 2       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25443
# 3       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        24956
# 4       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        23553
# 5       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        21700
# 6       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        19693
# 7       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        24634
# 8       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        24904
# 9       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25189
# 10      5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25327
# 11      5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25596
# ...

# %%
import pandas as pd
testfile2 = pd.read_csv("C:\\Users\\dgehan01\\Desktop\\python video\\test2.csv")
testfile2
# Out:
#      Attributed Touch Type Attributed Touch Time      Install Time  \
# 0                    click      26-07-2018 23:04  26-07-2018 23:59
# 1                    click      26-07-2018 01:09  26-07-2018 23:58
# 2                    click      26-07-2018 12:14  26-07-2018 23:56
# 3                    click      26-07-2018 22:30  26-07-2018 23:55
# 4                    click      26-07-2018 10:28  26-07-2018 23:43
# 5                    click      26-07-2018 23:16  26-07-2018 23:39
# 6                    click      26-07-2018 23:20  26-07-2018 23:27
# 7                    click      26-07-2018 13:48  26-07-2018 23:12
# 8                    click      26-07-2018 23:02  26-07-2018 23:11
# 9                    click      26-07-2018 22:52  26-07-2018 23:04
# 10                   click      26-07-2018 13:46  26-07-2018 23:03
# 11                   click      26-07-2018 22:51  26-07-2018 23:00
# 12                   click      26-07-2018 07:25  26-07-2018 22:57
# ...

# %%
import pandas as pd
test3 = pd.read_csv("C:\\Users\\dgehan01\\Desktop\\python video\\agodacsv.csv")
test3
# Out:
#      Attributed Touch Type Attributed Touch Time         Install Time  \
# 0                    click   2018-05-16 03:23:05  2018-05-16 03:23:14
# 1                    click   2018-02-14 12:57:47  2018-02-14 12:58:26
# 2                    click   2018-05-16 03:23:05  2018-05-16 03:23:14
# 3                    click   2018-05-16 03:23:05  2018-05-16 03:23:14
# 4                    click   2018-05-16 03:23:05  2018-05-16 03:23:14
# 5                    click   2018-08-08 21:24:47  2018-08-08 21:24:52
# 6                    click   2018-05-26 01:30:43  2018-05-26 01:30:48
# 7                    click   2018-05-14 02:07:40  2018-05-14 02:07:50
# 8                    click   2018-08-08 03:11:01  2018-08-08 03:15:11
# 9                    click   2018-03-21 13:51:43  2018-03-21 13:52:36
# 10                   click   2018-04-25 02:52:28  2018-04-25 02:52:32
# 11                   click   2018-05-15 13:25:01  2018-05-15 13:25:11
# ...

# %%
import pandas as pd
mydata = pd.read_csv("C:\\Users\\dgehan01\\Desktop\\python video\\test1.csv")
mydata
# Out:
#      campaignId                     campaignName  clientId  affiliateId  \
# 0       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        24825
# 1       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25525
# 2       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25443
# 3       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        24956
# 4       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        23553
# 5       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        21700
# 6       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        19693
# 7       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        24634
# 8       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        24904
# 9       5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25189
# 10      5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25327
# 11      5577671   Tokopedia_Exclusive_IOS_ID_Apr      1815        25596
# ...

# %%
import pandas as pd
data11 = pd.read_csv("D:\\Deepak Personal\\PYTHON and DS\\ANIL JADON\\Data-master\\Pandas_Exercise_Practice_Data\\cars1.csv")
data11
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %%
import numpy as np
array1 = np.array(data11)

# %%
array1 #list1 is first record
# Out:
# array([[18.0, 8, 307, ..., 70, 1, 'chevrolet chevelle malibu'],
#        [15.0, 8, 350, ..., 70, 1, 'buick skylark 320'],
#        [18.0, 8, 318, ..., 70, 1, 'plymouth satellite'],
#        ...,
#        [29.0, 4, 85, ..., 76, 1, 'chevrolet chevette'],
#        [24.5, 4, 98, ..., 76, 1, 'chevrolet woody'],
#        [29.0, 4, 90, ..., 76, 2, 'vw rabbit']], dtype=object)
